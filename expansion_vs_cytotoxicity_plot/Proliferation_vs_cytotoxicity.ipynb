# %% [markdown]
# This code is to plot avg. proliferation vs. cytotoxicity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


#This is the proliferation vs. cytotoxicity code
folder_name='proliferation_by_day'
filename='day9.dat'


path=os.path.join(folder_name,filename)
data=pd.read_csv(path, delimiter='\t',header=None)
data=np.asarray(data)
#print(data)
data_fc=np.transpose(data)


print(data_fc)
mean_fc=np.nanmean(data_fc, axis=1)

print(f" \n\n mean is = \n {mean_fc}")
# Out:
# [[23.4  23.4   7.96  7.7   5.8   6.34 26.07 13.74  1.45  3.15]
#  [ 2.28  7.12  0.82  2.22  9.   11.76 21.9  33.6   1.75  1.29]
#  [ 2.5   3.63  4.06 23.2   0.46 10.38 69.84 22.71 18.3  21.99]
#  [13.4  22.   10.42  7.98  5.76  4.1  31.8   4.8   0.95  2.24]
#  [19.24 15.18  1.04  9.68  8.18  6.18 15.6   8.13  1.24  2.65]
#  [18.26 15.18 16.38  5.5  20.64  5.3  34.32  7.17  1.35  2.32]
#  [10.2  12.    4.68  9.     nan   nan   nan   nan   nan   nan]
#  [ 9.6  15.    6.   11.1    nan   nan   nan   nan   nan   nan]
#  [15.   12.    0.4    nan   nan   nan   nan   nan   nan   nan]
#  [18.   14.4  16.8    nan   nan   nan   nan   nan   nan   nan]
#  [12.   11.7  10.8    nan   nan   nan   nan   nan   nan   nan]
#  [13.8  15.6  16.8    nan   nan   nan   nan   nan   nan   nan]]
#
#
#  mean is =
#  [11.901       9.174      17.707      10.345       8.712      12.642
#   8.97       10.425       9.13333333 16.4        11.5        15.4       ]

# %% [markdown]
# Poliferation (Day 9) vs. cytotoxicity CD107a (Day 10)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


#This is the proliferation vs. cytotoxicity code
folder_name='proliferation_by_day'
#filename='day9.dat'
filename='day9_donor_match.dat'

#cytoctoxicity data CD107

HEPG2=[49.68125,38.68171429,45.95375,58.13375,52.98625,52.02375,35.64666667,33.92666667,36.88,65.76]

PLC=[0.59,2.1215,1.5175,2.935,3.15375,3.18125,5.786666667,8.3,6.96,15.26]

SNU=[25.08,17.88,22.07,25.45,27.58,27.47,19.25,41.49,47.61,58.69]


Y=HEPG2

#labels=['cond1','cond2','cond3','cond4','cond5','cond6','cond9','cond10','cond11','cond12']
#labels=['C1','C2','C3','C4','C5','C6','C9','C10','C11','C12']
labels=['1','2','3','4','5','6','9','10','11','12']
# Set global font settings
plt.rcParams.update({
    'font.family': 'Arial',  # Use Arial font
    'font.size': 26,         # Set font size
})


path=os.path.join(folder_name,filename)
data=pd.read_csv(path, delimiter='\t',header=None)
data=np.asarray(data)
data_fc=np.transpose(data)



#print(data_fc)
mean_fc=np.nanmean(data_fc, axis=1)
mean_fc_modified=np.delete(mean_fc,[6,7]) #delete 7th and 8th element
print(f" \n\n mean is = \n {mean_fc_modified}")


# Define colors and marker size
colors = plt.get_cmap('tab10').colors  # You can use other colormaps
marker_size = 300

# Plot mean_fc_modified vs Y with labels

sc = plt.scatter(
    mean_fc_modified, 
    Y[:len(mean_fc_modified)], 
    c=np.arange(len(mean_fc_modified)),  # Color by index
    cmap='tab10',                      # Use a colormap for different colors
    edgecolor='black',                 # Black edge color
    s=marker_size,                     # Marker size
    linewidth=1.5                     # Marker edge width
)

# Add labels to each point with padding
label_offset_x =-0.3  # Horizontal offset for labels
label_offset_y =1.8  # Vertical offset for labels

for i, label in enumerate(labels):
    plt.text(
        mean_fc_modified[i] + label_offset_x, 
        Y[i] + label_offset_y, 
        label, 
        fontsize=18, 
        ha='left', 
        color='black'
    )

#plt.xlim(5,22)
plt.ylim(30,70)
# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 


plt.show()
# Out:
#
#
#  mean is =
#  [ 9.02625    10.2925     21.3675      8.50625     6.5875     11.6225
#   9.13333333 16.4        11.5        15.4       ]

# %% [markdown]
# Huh code

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


#This is the proliferation vs. cytotoxicity code
folder_name='proliferation_by_day'
#filename='day9.dat'
filename='day9_donor_match.dat'

#cytoctoxicity data CD107

HUH=[56.11,
36.60,
46.64,
59.15,
59.16,
54.62]



Y=HUH

labels=['cond1','cond2','cond3','cond4','cond5','cond6']
#labels=['1','2','3','4','5','6']
# Set global font settings
plt.rcParams.update({
    'font.family': 'Arial',  # Use Arial font
    'font.size': 26,         # Set font size
})


path=os.path.join(folder_name,filename)
data=pd.read_csv(path, delimiter='\t',header=None)
data=np.asarray(data)
data_fc=np.transpose(data)



#print(data_fc)
mean_fc=np.nanmean(data_fc, axis=1)
mean_fc_modified=np.delete(mean_fc,[6,7,8,9,10,11]) #delete 7th and 8th element
print(f" \n\n mean is = \n {mean_fc_modified}")


# Define colors and marker size
colors = plt.get_cmap('tab10').colors  # You can use other colormaps
marker_size = 300

# Plot mean_fc_modified vs Y with labels

sc = plt.scatter(
    mean_fc_modified, 
    Y[:len(mean_fc_modified)], 
    c=np.arange(len(mean_fc_modified)),  # Color by index
    cmap='tab10',                      # Use a colormap for different colors
    edgecolor='black',                 # Black edge color
    s=marker_size,                     # Marker size
    linewidth=1.5                     # Marker edge width
)

# Add labels to each point with padding
label_offset_x = 0.2  # Horizontal offset for labels
label_offset_y = 0.2  # Vertical offset for labels

for i, label in enumerate(labels):
    plt.text(
        mean_fc_modified[i] + label_offset_x, 
        Y[i] + label_offset_y, 
        label, 
        fontsize=14, 
        ha='left', 
        color='black'
    )

#plt.xlim(8,20)
# plt.ylim(30,70)
# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size) 


plt.show()
# Out:
#
#
#  mean is =
#  [ 9.02625 10.2925  21.3675   8.50625  6.5875  11.6225 ]

# %% [markdown]
# Proliferation vs. IFNg ( 3 donors) Sept 10, 2024
# Donors D32-D34
# For HepG2, SNU and PLC
#
# Condition 2, 3, 9, 10, 11, 12

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


#cytoctoxicity data IFNg
FC=[11.8,18.1,9.133333333,16.4,11.5,15.4]

HEPG2=[34.10666667,41.56666667,32.07666667,38.38,23.70666667,57.13666667]
PLC=[39.27333333,32.6,24.54333333,24.88,26.37333333,59.00333333]
SNU475=[51.97666667,53.53,29.34333333,37.64666667,39.57333333,57.60333333]

Y=SNU475

#labels=['cond2','cond3','cond9','cond10','cond11','cond12']

#labels=['C2','C3','C9','C10','C11','C12']
labels=['2','3','9','10','11','12']
# Set global font settings
plt.rcParams.update({
    'font.family': 'Arial',  # Use Arial font
    'font.size': 26,         # Set font size
})




mean_fc_modified=FC

# Define colors and marker size
colors = plt.get_cmap('tab10').colors  # You can use other colormaps
marker_size = 300

# Plot mean_fc_modified vs Y with labels

sc = plt.scatter(
    mean_fc_modified, 
    Y[:len(mean_fc_modified)], 
    c=np.arange(len(mean_fc_modified)),  # Color by index
    cmap='tab10',                      # Use a colormap for different colors
    edgecolor='black',                 # Black edge color
    s=marker_size,                     # Marker size
    linewidth=1.5                     # Marker edge width
)

# Add labels to each point with padding
label_offset_x = -0.1  # Horizontal offset for labels
label_offset_y = 1.8  # Vertical offset for labels

for i, label in enumerate(labels):
    plt.text(
        mean_fc_modified[i] + label_offset_x, 
        Y[i] + label_offset_y, 
        label, 
        fontsize=18, 
        ha='left', 
        color='black'
    )

#plt.xlim(8,20)
plt.ylim(23,65)
# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size)

# %%
Proliferation vs. IFNg ( 3 donors) Sept 10, 2024
Donors K, L and M
For Huh7

Condition 1, 2, 3, 12

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


#cytoctoxicity data IFNg
FC=[8.751333333,
14.86933333,
17.66533333,
24.91966667]

HUH=[6.173333333,
6.863333333,
7.25,
5.633333333]


Y=HUH

labels=['cond1','cond2','cond3','cond12']
# Set global font settings
plt.rcParams.update({
    'font.family': 'Arial',  # Use Arial font
    'font.size': 20,         # Set font size
})




mean_fc_modified=FC

# Define colors and marker size
colors = plt.get_cmap('tab10').colors  # You can use other colormaps
marker_size = 100

# Plot mean_fc_modified vs Y with labels

sc = plt.scatter(
    mean_fc_modified, 
    Y[:len(mean_fc_modified)], 
    c=np.arange(len(mean_fc_modified)),  # Color by index
    cmap='tab10',                      # Use a colormap for different colors
    edgecolor='black',                 # Black edge color
    s=marker_size,                     # Marker size
    linewidth=1.5                     # Marker edge width
)

# Add labels to each point with padding
label_offset_x = 0.2  # Horizontal offset for labels
label_offset_y = 0.2  # Vertical offset for labels

for i, label in enumerate(labels):
    plt.text(
        mean_fc_modified[i] + label_offset_x, 
        Y[i] + label_offset_y, 
        label, 
        fontsize=14, 
        ha='left', 
        color='black'
    )

#plt.xlim(8,20)
# plt.ylim(30,70)
# Access the Axes object
ax = plt.gca()

# Set the width of the x and y axes (spines)
axes_width_size=2
ax.spines['bottom'].set_linewidth(axes_width_size)
ax.spines['left'].set_linewidth(axes_width_size)
ax.spines['top'].set_linewidth(axes_width_size)  # Optional: set top spine width to 0 if not needed
ax.spines['right'].set_linewidth(axes_width_size)
